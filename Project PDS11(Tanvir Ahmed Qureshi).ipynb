# %%
#Project-1:
#Answer to the Q.N-1:

import pandas as pd


df=pd.read_csv("https://raw.githubusercontent.com/PulockDas/pd-12-resources/refs/heads/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Answer to the Q.N-2:

null_columns =df.columns[df.isnull().any()]
print(null_columns)
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
#Answer to the Q.N-3:

df['Age'].fillna(df['Age'].mean(), inplace=True)


df['Cabin'].fillna('Unknown', inplace=True)


print(df[['Age', 'Cabin']].isnull().sum())
# Out:
# Age      0
# Cabin    0
# dtype: int64

# %%
#Answer to the Q.N-4:
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("https://raw.githubusercontent.com/PulockDas/pd-12-resources/refs/heads/master/titanic.csv")

survival_counts = df.groupby(['Survived', 'Sex']).size().unstack()

survival_counts.plot(kind='bar', stacked=True, color=['blue', 'pink'])

plt.title("Titanic Survival Count by Gender")
plt.xlabel("Survival Status (0 = Dead, 1 = Survived)")
plt.ylabel("Number of Passengers")
plt.legend(title="Gender", labels=['Male', 'Female'])
plt.xticks(ticks=[0, 1], labels=['Dead', 'Survived'], rotation=0)


plt.show()

# %%
#Answer to the Q.N-5:

import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("https://raw.githubusercontent.com/PulockDas/pd-12-resources/refs/heads/master/titanic.csv")


survival_by_class = df.groupby(['Pclass', 'Survived', 'Sex']).size().unstack()


survival_by_class.plot(kind='bar', stacked=True, color=['blue', 'pink'], figsize=(8, 6))


plt.title("Titanic Survival by Passenger Class and Gender")
plt.xlabel("Passenger Class and Survival Status (0 = Dead, 1 = Survived)")
plt.ylabel("Number of Passengers")
plt.legend(title="Gender", labels=['Male', 'Female'])
plt.xticks(rotation=0)


plt.show()

# %%
#Answer to the Q.N-6:
import pandas as pd


df = pd.read_csv("https://raw.githubusercontent.com/PulockDas/pd-12-resources/refs/heads/master/titanic.csv")


df['AgeClass'] = df['Age'].apply(lambda age: 0 if age <= 16 else 
                                            1 if age <= 26 else 
                                            2 if age <= 36 else 
                                            3 if age <= 62 else 4)


print(df[['Age', 'AgeClass']].head(10))
# Out:
#     Age  AgeClass
# 0  22.0         1
# 1  38.0         3
# 2  26.0         1
# 3  35.0         2
# 4  35.0         2
# 5   NaN         4
# 6  54.0         3
# 7   2.0         0
# 8  27.0         2
# 9  14.0         0

# %%
#Answer to the Q.N-7:

df.drop(columns=['Age'], inplace=True)


print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#              Ticket     Fare Cabin Embarked  AgeClass
# 0         A/5 21171   7.2500   NaN        S         1
# 1          PC 17599  71.2833   C85        C         3
# 2  STON/O2. 3101282   7.9250   NaN        S         1
# 3            113803  53.1000  C123        S         2
# ...

# %%
#Answer to the Q.N-8:
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("https://raw.githubusercontent.com/PulockDas/pd-12-resources/refs/heads/master/titanic.csv")


df['AgeClass'] = df['Age'].apply(lambda age: 0 if age <= 16 else 
                                            1 if age <= 26 else 
                                            2 if age <= 36 else 
                                            3 if age <= 62 else 4)


df.drop(columns=['Age'], inplace=True)


survival_by_age = df.groupby(['AgeClass', 'Survived', 'Sex']).size().unstack()


survival_by_age.plot(kind='bar', stacked=True, color=['blue', 'pink'], figsize=(8, 6))


plt.title("Titanic Survival by Age Class and Gender")
plt.xlabel("Age Class and Survival Status (0 = Dead, 1 = Survived)")
plt.ylabel("Number of Passengers")
plt.legend(title="Gender", labels=['Male', 'Female'])
plt.xticks(rotation=0)


plt.show()

# %%
#Assignment:
#2 No:
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("https://raw.githubusercontent.com/PulockDas/pd-12-resources/refs/heads/master/titanic.csv")


dead_passengers = df[df['Survived'] == 0]


plt.figure(figsize=(8, 6))


plt.scatter(dead_passengers[dead_passengers['Sex'] == 'male']['Age'], 
            dead_passengers[dead_passengers['Sex'] == 'male']['Fare'], 
            color='blue', label='Male', alpha=0.6)


plt.scatter(dead_passengers[dead_passengers['Sex'] == 'female']['Age'], 
            dead_passengers[dead_passengers['Sex'] == 'female']['Fare'], 
            color='yellow', label='Female', alpha=0.6)

plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Scatter Plot of Dead Male and Female Passengers (Titanic)")
plt.legend()
plt.grid(True)


plt.show()

# %%
#Project-2:
#Answer to the Q N-1:

import pandas as pd
import random


data = []
for i in range(1, 51):
    registration_number = f"REG-{i:03d}"
    name = f"Student {i}"
    marks = random.randint(0, 100)  
    data.append([registration_number, name, marks])


df = pd.DataFrame(data, columns=["Registration Number", "Name", "TT-1 Marks"])


df.to_csv("term-test-1-result.csv", index=False)


df.head()
# Out:
#   Registration Number       Name  TT-1 Marks
# 0             REG-001  Student 1          74
# 1             REG-002  Student 2          84
# 2             REG-003  Student 3          70
# 3             REG-004  Student 4          74
# 4             REG-005  Student 5          23

# %%
#Answer to the Q N-2:

import pandas as pd
import random


df_tt1 = pd.read_csv("term-test-1-result.csv")


df_tt2 = df_tt1.copy()
df_tt2['TT-2 Marks'] = [random.randint(0, 100) for _ in range(len(df_tt2))]


df_tt2.to_csv("term-test-2-result.csv", index=False)


df_tt2.head()
# Out:
#   Registration Number       Name  TT-1 Marks  TT-2 Marks
# 0             REG-001  Student 1          74          98
# 1             REG-002  Student 2          84          79
# 2             REG-003  Student 3          70           0
# 3             REG-004  Student 4          74          87
# 4             REG-005  Student 5          23          30

# %%
#Answer to the Q N-3:
import pandas as pd


df_tt1 = pd.read_csv("term-test-1-result.csv")
df_tt2 = pd.read_csv("term-test-2-result.csv")

merged_df = pd.merge(df_tt1, df_tt2, on="Registration Number")


print(merged_df.head())
# Out:
#   Registration Number     Name_x  TT-1 Marks_x     Name_y  TT-1 Marks_y  \
# 0             REG-001  Student 1            74  Student 1            74
# 1             REG-002  Student 2            84  Student 2            84
# 2             REG-003  Student 3            70  Student 3            70
# 3             REG-004  Student 4            74  Student 4            74
# 4             REG-005  Student 5            23  Student 5            23
#
#    TT-2 Marks
# 0          98
# 1          79
# 2           0
# 3          87
# 4          30

# %%
#Answer to the Q N-4:
import pandas as pd


df_tt1 = pd.read_csv("term-test-1-result.csv")
df_tt2 = pd.read_csv("term-test-2-result.csv")


merged_df = pd.merge(df_tt1, df_tt2, on="Registration Number")


print("Columns in merged dataframe:", merged_df.columns)


merged_df.rename(columns={'TT-1 Marks_x': 'TT-1 Marks', 'TT-2 Marks_y': 'TT-2 Marks'}, inplace=True)

print("Updated columns in merged dataframe:", merged_df.columns)


merged_df['Best Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].max(axis=1)


merged_df['Average Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].mean(axis=1)


print(merged_df[['Registration Number', 'Name', 'TT-1 Marks', 'TT-2 Marks', 'Best Marks', 'Average Marks']].head())
# Out:
# Columns in merged dataframe: Index(['Registration Number', 'Name_x', 'TT-1 Marks_x', 'Name_y',
#        'TT-1 Marks_y', 'TT-2 Marks'],
#       dtype='object')
# Updated columns in merged dataframe: Index(['Registration Number', 'Name_x', 'TT-1 Marks', 'Name_y', 'TT-1 Marks_y',
#        'TT-2 Marks'],
#       dtype='object')
# ----------------------------------------------------------------
# KeyError                       Traceback (most recent call last)
# Cell In[41], line 26
#      20 merged_df['Best Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].max(axis=1)
#      23 merged_df['Average Marks'] = merged_df[['TT-1 Marks', 'TT-2 Marks']].mean(axis=1)
# ---> 26 print(merged_df[['Registration Number', 'Name', 'TT-1 Marks', 'TT-2 Marks', 'Best Marks', 'Average Marks']].head())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# ...

# %%
#Answer to the Q N-5:
merged_df.drop(columns=['TT-1 Marks', 'TT-2 Marks'], inplace=True)


print(merged_df[['Registration Number', 'Name', 'Best Marks', 'Average Marks']].head())
# Out:
# ----------------------------------------------------------------
# KeyError                       Traceback (most recent call last)
# Cell In[39], line 2
#       1 #Answer to the Q N-5:
# ----> 2 merged_df.drop(columns=['TT-1 Marks', 'TT-2 Marks'], inplace=True)
#       5 print(merged_df[['Registration Number', 'Name', 'Best Marks', 'Average Marks']].head())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
# ...

# %%
#Answer to the Q N-6:
merged_df.to_csv('final term test result.csv', index=False)


print("The dataframe has been saved to 'final term test result.csv'")
# Out:
# The dataframe has been saved to 'final term test result.csv'

# %%
#Answer to the Q N-7:
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


merged_df = pd.read_csv("final term test result.csv")


X = merged_df[['Average Marks']].values  # Reshape it to fit the model


kmeans = KMeans(n_clusters=3, random_state=42)
merged_df['Cluster'] = kmeans.fit_predict(X)


plt.figure(figsize=(8, 6))
plt.scatter(merged_df['Average Marks'], [1]*len(merged_df), c=merged_df['Cluster'], cmap='viridis', s=100)
plt.title("K-Means Clustering of Average Marks")
plt.xlabel("Average Marks")
plt.yticks([])
plt.colorbar(label='Cluster')
plt.show()


print("Cluster Centers:", kmeans.cluster_centers_)
# Out:
# C:\Users\qures\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\qures\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Cluster Centers: [[82.27777778]
#  [38.14285714]
#  [62.825     ]]
